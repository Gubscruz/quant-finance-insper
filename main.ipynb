# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading + Cleaning the Data

# %%
fname = "SPX_database_2010.xlsx"
df_SPX = pd.read_excel(fname, sheet_name="SPX_memb")[["Ticker", "Name"]]
df_mktcap_inicial = pd.read_excel(fname, sheet_name="mkt_cap")
df_price_inicial  = pd.read_excel(fname, sheet_name="prices")
df_total_ret_inicial = pd.read_excel(fname, sheet_name="total_ret")

# %%
for df in (df_price_inicial, df_mktcap_inicial, df_total_ret_inicial):
    df["Dates"] = pd.to_datetime(df["Dates"], errors="coerce")
    df.sort_values("Dates", inplace=True)
    df.reset_index(drop=True, inplace=True)

df_price = df_price_inicial[df_price_inicial["Dates"].dt.year >= 2014].reset_index(drop=True)
df_mktcap = df_mktcap_inicial[df_mktcap_inicial["Dates"].dt.year >= 2014].reset_index(drop=True)
df_total_ret = df_total_ret_inicial[df_total_ret_inicial["Dates"].dt.year >= 2014].reset_index(drop=True)

# %%
def _complete_cols(df):
    cols = [c for c in df.columns if c != "Dates"]
    complete = [c for c in cols if not df[c].isna().any()]
    return df[["Dates"] + complete].copy()

df_price_v1 = _complete_cols(df_price)
df_mktcap_v1 = _complete_cols(df_mktcap)
df_total_ret_v1 = _complete_cols(df_total_ret)

# %% [markdown]
# ### Choosing 30 stocks and aligning data

# %%
def _choose_30(spx_df, px_df, tri_df, mkt_df, random_state=42):
    spx = set(spx_df["Ticker"].astype(str).str.strip())
    tick_px = [c for c in px_df.columns  if c != "Dates" and c in spx]
    tick_tri = [c for c in tri_df.columns if c != "Dates"]
    tick_mkt = [c for c in mkt_df.columns if c != "Dates"]
    
    eligible = sorted(set(tick_px) & set(tick_tri) & set(tick_mkt))
    rng = np.random.default_rng(random_state)
    
    return sorted(rng.choice(eligible, size=30, replace=False))


def _align_on_dates(px, tri, mkt, tickers):
    p = px[["Dates"] + tickers].copy()
    t = tri[["Dates"] + tickers].copy()
    m = mkt[["Dates"] + tickers].copy()

    pt = p.merge(t, on="Dates", suffixes=("_px", "_tri"))
    ptm = pt.merge(m, on="Dates")
    prices = pd.concat([ptm[["Dates"]], ptm[[f"{x}_px"  for x in tickers]].set_axis(tickers, axis=1)], axis=1)
    tris = pd.concat([ptm[["Dates"]], ptm[[f"{x}_tri" for x in tickers]].set_axis(tickers, axis=1)], axis=1)
    mktcap = pd.concat([ptm[["Dates"]], ptm[[x for x in tickers]]], axis=1)
    
    return prices, tris, mktcap


tickers30 = _choose_30(df_SPX, df_price_v1, df_total_ret_v1, df_mktcap_v1, random_state=42)
prices_30, tri_30, mktcap_30 = _align_on_dates(df_price_v1, df_total_ret_v1, df_mktcap_v1, tickers30)

# %% [markdown]
# ### Separating month windows

# %%
dates_series = pd.Series(prices_30["Dates"]).reset_index(drop=True)
groups = dates_series.groupby([dates_series.dt.year, dates_series.dt.month], sort=True).groups

month_windows = []
for _, locs in groups.items():
    locs = sorted(locs)
    month_windows.append((locs[0], locs[-1]))

# %%
mktcap_30
# Out:
#           Dates  ARE UN Equity  ATO UN Equity  AVY UN Equity  BK UN Equity  \
# 0    2014-01-01      4544.2116      4131.2625      4849.1489    40129.3449
# 3018     13218.7039     44966.8399     18989.4409
# 3019     13450.6110     44960.6269     18785.6575
# 3020     13182.2614     43295.5336     18463.1655
# 3021     13016.6135     42655.5910     18132.7595
# 3022     12813.1960     41372.5993     17928.9762
#
# [3023 rows x 31 columns]

# %% [markdown]
# # Calculate daily returns and values

# %%
tickers = tickers30
n = len(tickers)

capital_ew = 100_000_000.0
capital_vw = 100_000_000.0

ew_vals_parts = []
vw_vals_parts = []
w_ew_rows, w_vw_rows = [], []
s_ew_rows, s_vw_rows = [], []


for start_idx, end_idx in month_windows:
    prev_idx = start_idx - 1

    w_ew = pd.Series(1.0 / n, index=tickers)

    prev_mktcap = (
        mktcap_30.iloc[prev_idx][tickers]      # positional previous row
        .astype(float)
        .replace([np.inf, -np.inf], np.nan)
        .fillna(0.0)
    )
    total_prev = float(prev_mktcap.sum())
    w_vw = (prev_mktcap / total_prev) if total_prev > 0 else pd.Series(1.0 / n, index=tickers)

    prices_0 = (prices_30.loc[start_idx, tickers])
    px_safe = prices_0.replace(0.0, np.nan)

    shares_ew = (w_ew * capital_ew) / px_safe
    shares_vw = (w_vw * capital_vw) / px_safe
    shares_ew = shares_ew
    shares_vw = shares_vw

    tri_win = tri_30.loc[start_idx:end_idx, tickers]
    tri_base = tri_win.iloc[0].replace(0.0, np.nan)
    growth = tri_win.divide(tri_base, axis=1).fillna(1.0)

    start_pos_val_ew = shares_ew * prices_0
    start_pos_val_vw = shares_vw * prices_0

    vals_ew = growth.mul(start_pos_val_ew, axis=1).sum(axis=1)
    vals_vw = growth.mul(start_pos_val_vw, axis=1).sum(axis=1)

    ew_vals_parts.append(vals_ew)
    vw_vals_parts.append(vals_vw)

    rebalance_date = prices_30.loc[start_idx, "Dates"]
    w_ew_rows.append({"rebalance_date": rebalance_date, **{f"w_{t}": w_ew[t] for t in tickers}})
    w_vw_rows.append({"rebalance_date": rebalance_date, **{f"w_{t}": w_vw[t] for t in tickers}})
    s_ew_rows.append({"rebalance_date": rebalance_date, **{f"s_{t}": shares_ew[t] for t in tickers}})
    s_vw_rows.append({"rebalance_date": rebalance_date, **{f"s_{t}": shares_vw[t] for t in tickers}})

    capital_ew = float(vals_ew.iloc[-1])
    capital_vw = float(vals_vw.iloc[-1])



EW_Value = pd.concat(ew_vals_parts)
VW_Value = pd.concat(vw_vals_parts)
EW_Value.index = prices_30.loc[EW_Value.index, "Dates"].values
VW_Value.index = prices_30.loc[VW_Value.index, "Dates"].values

EW_Return = EW_Value.pct_change().rename("EW_Return")
VW_Return = VW_Value.pct_change().rename("VW_Return")

daily_returns = pd.concat([EW_Return, VW_Return], axis=1)
daily_values = pd.concat([EW_Value.rename("EW_Value"), VW_Value.rename("VW_Value")], axis=1)

weights_ew = pd.DataFrame(w_ew_rows)
weights_vw = pd.DataFrame(w_vw_rows)
shares_ew = pd.DataFrame(s_ew_rows)
shares_vw = pd.DataFrame(s_vw_rows)

display(daily_returns, daily_values, weights_ew, weights_vw, shares_ew, shares_vw)
# Out:
# /var/folders/pm/ps47mfm943x_nqjshcjsk5ch0000gn/T/ipykernel_63056/1279008340.py:64: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# %%
plt.figure(figsize=(11,5))
daily_values.plot(ax=plt.gca())
plt.title("Portfolio Value (EW vs VW)")
plt.xlabel("Date")
plt.ylabel("Value")
plt.legend()
plt.grid(True)

plt.figure(figsize=(11,5))
norm_vals = pd.DataFrame({
    "EW_Index": EW_Value / EW_Value.dropna().iloc[0],
    "VW_Index": VW_Value / VW_Value.dropna().iloc[0],
})
norm_vals.plot(ax=plt.gca())
plt.title("Cumulative Performance (Indexed to 1.0)")
plt.xlabel("Date")
plt.ylabel("Index")
plt.legend()
plt.grid(True)

# plt.figure(figsize=(11,5))
# rolling_vol = pd.DataFrame({
#     "EW_RollingVol_21d": daily_returns["EW_Return"].rolling(21).std() * np.sqrt(252),
#     "VW_RollingVol_21d": daily_returns["VW_Return"].rolling(21).std() * np.sqrt(252),
# })
# rolling_vol.plot(ax=plt.gca())
# plt.title("Rolling Volatility (21d, Annualized)")
# plt.xlabel("Date")
# plt.ylabel("Volatility")
# plt.legend()
# plt.grid(True)

plt.show()

# %% [markdown]
# # Calculating the yearly turnover
#
# $$
# \text{Turnover} = \frac{\min(\text{Total Buys}, \text{Total Sells})}{\text{Average Assets}}
# $$

# %%
prices = prices_30[["Dates"] + tickers].copy()
prices["Dates"] = pd.to_datetime(prices["Dates"])
prices = prices.set_index("Dates")

def turnover(shares_df):
    rows = []
    for i in range(1, len(shares_df)):
        date_now = pd.to_datetime(shares_df.loc[i, "rebalance_date"])

        prev_shares = shares_df.loc[i-1, [f"s_{t}" for t in tickers]].to_numpy(float)
        curr_shares = shares_df.loc[i, [f"s_{t}" for t in tickers]].to_numpy(float)
        px = prices.loc[date_now, tickers].to_numpy(float)

        prev_val = prev_shares * px
        curr_val = curr_shares * px
        diff = curr_val - prev_val

        buys = diff[diff > 0].sum()
        sells = (-diff[diff < 0]).sum()
        assets = curr_val.sum()

        rows.append({
            "date": date_now, 
            "buys": buys, "sells": sells, 
            "assets": assets
        })

    trades = pd.DataFrame(rows)
    trades["year"] = trades["date"].dt.year
    
    out = (
        trades
        .groupby("year", as_index=False)
        .agg(total_buys=("buys", "sum"),
            total_sells=("sells", "sum"),
            avg_assets=("assets", "mean"))
    )
    out["turnover"] = out[["total_buys", "total_sells"]].min(axis=1) / out["avg_assets"]
    return out[["year", "turnover", "total_buys", "total_sells", "avg_assets"]]

turnover_ew = turnover(shares_ew)
turnover_vw = turnover(shares_vw)

display(turnover_ew, turnover_vw)
# Out:
#     year  turnover    total_buys   total_sells    avg_assets
# 0   2014  0.203432  2.593726e+07  2.188949e+07  1.076011e+08
# 1   2015  0.275770  3.413059e+07  3.543808e+07  1.237649e+08
# 2   2016  0.319488  4.183278e+07  4.134835e+07  1.294206e+08
# 3   2017  0.233013  3.739787e+07  4.003051e+07  1.604971e+08
# 4   2018  0.277943  5.802531e+07  5.277527e+07  1.898781e+08
# 5   2019  0.262233  5.488247e+07  5.082968e+07  1.938344e+08
# 6   2020  0.436488  9.293517e+07  9.276808e+07  2.125330e+08
# 7   2021  0.285116  8.350691e+07  1.007205e+08  2.928872e+08
# 8   2022  0.355393  1.043897e+08  1.051490e+08  2.937307e+08
# 9   2023  0.327275  1.020014e+08  1.067812e+08  3.116688e+08
# 10  2024  0.269129  1.141343e+08  1.008195e+08  3.746141e+08
# 11  2025  0.204597  9.747037e+07  8.389063e+07  4.100279e+08
#     year  turnover    total_buys   total_sells    avg_assets
# 0   2014  0.393523  4.848864e+07  4.252915e+07  1.080729e+08
# 1   2015  0.086927  1.028788e+07  1.399252e+07  1.183504e+08
# 2   2016  0.077427  9.546836e+06  1.253124e+07  1.233006e+08
# 3   2017  0.068024  9.943024e+06  1.109216e+07  1.461688e+08
# 4   2018  0.087578  1.640497e+07  1.574924e+07  1.798304e+08
# 5   2019  0.097519  2.350846e+07  1.784711e+07  1.830113e+08
# 6   2020  0.115606  2.422415e+07  3.778843e+07  2.095403e+08
# 7   2021  0.084119  2.382016e+07  4.106928e+07  2.831716e+08
# 8   2022  0.105117  2.807167e+07  3.447599e+07  2.670504e+08
# 9   2023  0.066070  1.701132e+07  2.655603e+07  2.574733e+08
# 10  2024  0.066649  2.153752e+07  3.081860e+07  3.231486e+08
# 11  2025  0.049543  3.269798e+07  1.809583e+07  3.652556e+08

# %%
turnover_vw['turnover'].mean()
# Out:
# np.float64(0.10817534770815011)

# %%
turnover_ew['turnover'].mean()
# Out:
# np.float64(0.2874896328871151)

# %% [markdown]
# ### Daily return per stock + Covariance matrix

# %%
stock_returns = prices.pct_change().dropna()
cov_matrix = stock_returns.cov()
corr_matrix = stock_returns.corr()

print("Stock Returns:\n", stock_returns.head())
print("Covariance Matrix:\n", cov_matrix)
print("Correlation Matrix:\n", corr_matrix)
# Out:
# Stock Returns:
#              ARE UN Equity  ATO UN Equity  AVY UN Equity  BK UN Equity  \
# Dates
# 2014-01-02       0.001729      -0.016513      -0.011556     -0.010876
# 2014-01-03       0.010513       0.001567      -0.001209      0.011574
# 2014-01-06      -0.003727      -0.012293      -0.002422     -0.000286
# 2014-01-07       0.002805       0.022403       0.003844     -0.011731
# 2014-01-08      -0.002176       0.005312      -0.003225      0.003474
#
#             CHRW UW Equity  CLX UN Equity  FCX UN Equity  GIS UN Equity  \
# Dates
# 2014-01-02       -0.008913      -0.017249      -0.002915      -0.010218
# 2014-01-03       -0.009339       0.003620      -0.008238      -0.002834
# 2014-01-06       -0.011697      -0.004153      -0.008039       0.001624
# 2014-01-07        0.001237      -0.006805      -0.009724       0.010336
# 2014-01-08       -0.007234      -0.016576      -0.012548      -0.025677
#
#             GM UN Equity  GOOGL UW Equity  ...  ON UW Equity  PFE UN Equity  \
# Dates                                      ...
# 2014-01-02      0.001957        -0.006775  ...     -0.027913      -0.005552
# 2014-01-03     -0.033700        -0.007288  ...      0.004994       0.001971
# 2014-01-06      0.020975         0.011138  ...     -0.002484       0.000982
# 2014-01-07     -0.004950         0.019027  ...      0.008717       0.006222
# 2014-01-08      0.005473         0.002316  ...      0.054321       0.006829
#
#             PHM UN Equity  PRU UN Equity  RCL UN Equity  SJM UN Equity  \
# Dates
# 2014-01-02      -0.014237      -0.015832      -0.005272      -0.015345
    Sharpe = (Execss_EW.mean() / Execss_EW.std(ddof=1)) * np.sqrt(252)

    GeometricAvg = ((1 + retornos).prod())**(1/len(retornos)) - 1
    GeometricAvg_Annual = (1 + GeometricAvg)**252 - 1

    Std_Annual = retornos.std(ddof=1) * np.sqrt(252)
    std_Anual_bench = (BenchMark["retornos"].std(ddof=1)) * np.sqrt(252)

    Excess_Bench = retornos - BenchMark["retornos"]

    IR_BM = (Excess_Bench.mean() / Excess_Bench.std(ddof=1)) * np.sqrt(252)
    return Sharpe, GeometricAvg_Annual, Std_Annual, IR_BM, std_Anual_bench

# %% [markdown]
# # Data Cleaning

# %%
#Do
df_price = df_price.set_index("Dates")
df_sofr = pd.read_excel("sofr.xlsx")
df_sofr.rename(columns={"Data": "Dates"}, inplace=True)
df_sofr["Dates"] = pd.to_datetime(df_sofr["Dates"]) 
df_sofr = df_sofr.set_index("Dates").sort_index()
df_sofr["Taxa_diaria"] = ((1 + df_sofr["Price"]) ** (1/252)) -1
df_price.index = pd.to_datetime(df_price.index)
# calcula retornos percentuais
df_benchmark = pd.read_excel("Nasdaq100.xlsx")
df_benchmark = df_benchmark.set_index("Dates").sort_index()
df_benchmark["retornos"] = df_benchmark.pct_change()

# %%
Sharpe_W, GeometricAvg_Annual_W, Std_Annual_W, IR_BM_W, std_Anual_bench_W = Statistics(daily_returns["EW_Return"].dropna(), df_sofr.dropna(), df_benchmark.dropna())
Sharpe_V, GeometricAvg_Annual_V, Std_Annual_V, IR_BM_V, std_Anual_bench_V = Statistics(daily_returns["VW_Return"].dropna(), df_sofr.dropna(), df_benchmark.dropna())

# %%
print(Sharpe_W, GeometricAvg_Annual_W, Std_Annual_W, IR_BM_W, std_Anual_bench_W)
print(Sharpe_V, GeometricAvg_Annual_V, Std_Annual_V, IR_BM_V, std_Anual_bench_V)
# Out:
# 0.6904523757162329 0.1291466912763679 0.17894433395351128 -0.3006272180029273 0.21516788292779862
# 0.5899980405903924 0.12021055143004822 0.2021115537283747 -0.4049018866577898 0.21516788292779862

# %% [markdown]
# # Plots

# %%
measures = ["Sharpe", "Geometric Avg Annual", "Std Annual", "IR BenchMark", "Std Anual Bench"]
values_W = [Sharpe_W, GeometricAvg_Annual_W, Std_Annual_W, IR_BM_W, std_Anual_bench_W]
values_V = [Sharpe_V, GeometricAvg_Annual_V, Std_Annual_V, IR_BM_V, std_Anual_bench_V]

df = pd.DataFrame({"E": values_W, "V": values_V}, index=measures)

for metric in measures:
    fig, ax = plt.subplots(figsize=(6, 4))
    df.loc[metric].plot(kind="bar", ax=ax) 
    ax.set_title(f"Comparison: {metric} (Equal Weighted vs Value Weighted)")
    ax.set_xlabel("Portfólio")
    ax.set_ylabel(metric)
    ax.grid(axis="y", linestyle="--", alpha=0.4)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Part C

# %%
df = tri_30.copy()
df = df.set_index("Dates").sort_index()

assets = df.select_dtypes(include=[np.number]).columns
df = df[assets]

month_end_tri = df.resample("M").last()
monthly_returns = month_end_tri.pct_change().dropna(how="all")

monthly_returns
# Out:
# /var/folders/pm/ps47mfm943x_nqjshcjsk5ch0000gn/T/ipykernel_63056/870848131.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#
#
#             SNA UN Equity  UDR UN Equity  VLO UN Equity  ZBH UN Equity
# Dates
# 2014-02-28       0.124538       0.060395      -0.056100      -0.001383
# 2014-03-31       0.011682       0.000775       0.106712       0.010280
# 2014-04-30       0.022208       0.011322       0.076648       0.023473
# 2014-05-31       0.014815       0.064192      -0.015156       0.077995
# 2014-06-30       0.010658       0.040334      -0.106155      -0.002618
# ...                   ...            ...            ...            ...
# 2025-04-30      -0.068841      -0.062720      -0.120996      -0.089503
# 2025-05-31       0.028810      -0.010745       0.120443      -0.105580
# 2025-06-30      -0.029837      -0.014482       0.042258      -0.007826
# 2025-07-31       0.032168      -0.027499       0.029906       0.004824
# 2025-08-31      -0.015972      -0.020361      -0.032117      -0.012984
#
# [139 rows x 30 columns]

# %% [markdown]
# # Optimal Weights
#
# $$
# \text{Optimal Weights} = \frac{\Sigma^{-1} \mu}{\mathbf{1}^T \Sigma^{-1} \mu}
# $$

# %%
df = tri_30.copy()
df = df.set_index(pd.to_datetime(df["Dates"])).drop(columns=["Dates"]).sort_index()
df = df.select_dtypes(include=[np.number])

month_end_tri = df.resample("M").last()
monthly_returns = month_end_tri.pct_change().dropna(how="all")
monthly_returns
# Out:
# /var/folders/pm/ps47mfm943x_nqjshcjsk5ch0000gn/T/ipykernel_63056/1732495451.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   month_end_tri = df.resample("M").last()
#             ARE UN Equity  ATO UN Equity  AVY UN Equity  BK UN Equity  \
# Dates
# 2014-02-28       0.033081      -0.031940       0.011163      0.001251
# 2014-03-31       0.011354       0.022343       0.023031      0.102814
# 2014-04-30       0.017365       0.082962      -0.039668     -0.035471
# 2014-05-31       0.030750      -0.011214       0.041924      0.020374
# 2014-06-30       0.029997       0.065868       0.017932      0.084489
# ...                   ...            ...            ...           ...
# 2025-04-30      -0.214571       0.039139      -0.038546     -0.035168
# 2025-05-31      -0.033994      -0.031688       0.038689      0.101977
# 2025-06-30       0.053569      -0.003685      -0.007523      0.028213
# 2025-07-31       0.052320       0.011745      -0.043882      0.119337
# 2025-08-31      -0.004972      -0.000705      -0.014365     -0.019221
#
#             CHRW UW Equity  CLX UN Equity  FCX UN Equity  GIS UN Equity  \
# Dates
# 2014-02-28       -0.114110      -0.011212       0.006479       0.041858
# 2014-03-31        0.017051       0.008364       0.013795       0.035778
# 2014-04-30        0.124261       0.038689       0.049285       0.031338
# 2014-05-31        0.016298      -0.011908      -0.009310       0.036024
# 2014-06-30        0.071936       0.019860       0.071953      -0.043510
# ...                    ...            ...            ...            ...
# 2025-04-30       -0.128711      -0.025140      -0.044058      -0.041052
# 2025-05-31        0.075656      -0.073225       0.067999      -0.043708
# 2025-06-30        0.006262      -0.089553       0.126559      -0.045153
# 2025-07-31        0.201876       0.045726      -0.068586      -0.043395
# 2025-08-31       -0.018904      -0.018877      -0.014911      -0.001224
#
#             GM UN Equity  GOOGL UW Equity  ...  ON UW Equity  PFE UN Equity  \
# Dates                                      ...
# 2014-02-28      0.003326         0.029371  ...      0.117225       0.065211
# 2014-03-31     -0.040804        -0.083199  ...      0.006424       0.000312
# 2014-04-30      0.001742        -0.041090  ...      0.001064      -0.026153
# 2014-05-31      0.002901         0.068763  ...     -0.076514      -0.044261
# 2014-06-30      0.058356         0.022776  ...      0.051784       0.001687
# ...                  ...              ...  ...           ...            ...
# 2025-04-30     -0.038061         0.026900  ...     -0.024330      -0.036700
# 2025-05-31      0.096595         0.081488  ...      0.058438      -0.019117
# 2025-06-30     -0.004928         0.027368  ...      0.247263       0.031928
# 2025-07-31      0.083926         0.088914  ...      0.075367      -0.022525
# 2025-08-31     -0.019498        -0.016151  ...      0.008162       0.006226
#
#             PHM UN Equity  PRU UN Equity  RCL UN Equity  SJM UN Equity  \
# Dates
# 2014-02-28       0.032972       0.008580       0.072246       0.043982
# 2014-03-31      -0.083505       0.000828       0.030796      -0.027699
# 2014-04-30      -0.041687      -0.046899      -0.026210      -0.005761
# 2014-05-31       0.063618       0.024970       0.045667       0.067477
# 2014-06-30       0.033305       0.080452       0.005607       0.038697
# ...                   ...            ...            ...            ...
# 2025-04-30      -0.002140      -0.080319       0.046096      -0.018071
# 2025-05-31      -0.044356       0.024387       0.195710      -0.022260
# 2025-06-30       0.078191       0.034171       0.222026      -0.127967
# 2025-07-31       0.070737      -0.035927       0.015105       0.093076
# 2025-08-31       0.029667      -0.032053      -0.016265       0.005499
#
#             SNA UN Equity  UDR UN Equity  VLO UN Equity  ZBH UN Equity
# Dates
# 2014-02-28       0.124538       0.060395      -0.056100      -0.001383
# 2014-03-31       0.011682       0.000775       0.106712       0.010280
# 2014-04-30       0.022208       0.011322       0.076648       0.023473
# 2014-05-31       0.014815       0.064192      -0.015156       0.077995
# 2014-06-30       0.010658       0.040334      -0.106155      -0.002618
# ...                   ...            ...            ...            ...
# 2025-04-30      -0.068841      -0.062720      -0.120996      -0.089503
# 2025-05-31       0.028810      -0.010745       0.120443      -0.105580
# 2025-06-30      -0.029837      -0.014482       0.042258      -0.007826
# 2025-07-31       0.032168      -0.027499       0.029906       0.004824
# 2025-08-31      -0.015972      -0.020361      -0.032117      -0.012984
#
# [139 rows x 30 columns]

# %%
sofr = pd.read_excel("SOFR.xlsx")
sofr["Data"] = pd.to_datetime(sofr["Data"])
sofr = sofr.set_index("Data").sort_index()

rf_ann = sofr["Price"].astype(float)

# Treat as daily overnight annualized rate; convert to daily simple return via ACT/360,
# then compound within each calendar month to get the *monthly* risk-free return.
rf_daily_simple = rf_ann / 360.0
monthly_rf = ((1.0 + rf_daily_simple).resample("M").prod() - 1.0).dropna()
# Out:
# /var/folders/pm/ps47mfm943x_nqjshcjsk5ch0000gn/T/ipykernel_63056/48486290.py:10: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_rf = ((1.0 + rf_daily_simple).resample("M").prod() - 1.0).dropna()

# %%
mr = monthly_returns.copy()
rf = monthly_rf.copy()

common_idx = mr.index.intersection(rf.index)
mr = mr.loc[common_idx]
rf = rf.loc[common_idx]

monthly_excess = mr.sub(rf, axis=0).dropna(how="all")

# %%
mu = monthly_excess.mean().to_numpy()
Sigma = monthly_excess.cov().to_numpy()
n = mu.size

invS = np.linalg.pinv(Sigma)
ones = np.ones(n)

A = ones @ invS @ ones
B = ones @ invS @ mu
C = mu   @ invS @ mu
D = A * C - B * B

w_gmv = (invS @ ones) / A
mu_gmv = float(w_gmv @ mu)
sig_gmv = float(np.sqrt(1.0 / A))

def w_for_r(r):
    lam1 = (C - B * r) / D
    lam2 = (A * r - B) / D
    return lam1 * (invS @ ones) + lam2 * (invS @ mu)

# Sweep target returns from GMV return to the max asset mean
target_returns = np.linspace(mu_gmv, float(mu.max()), 120)
W = np.vstack([w_for_r(r) for r in target_returns])
returns = W @ mu
volatilities = np.sqrt(np.einsum("ij,jk,ik->i", W, Sigma, W))

# Keep only the efficient arc (should already be efficient since we start at mu_gmv)
order = np.argsort(volatilities)
vols_eff = volatilities[order]
rets_eff = returns[order]

plt.figure(figsize=(7, 5))
plt.plot(vols_eff, rets_eff, lw=2, label="Efficient frontier (unconstrained)")
plt.scatter([sig_gmv], [mu_gmv], s=60, zorder=3, label="GMV")
plt.xlabel("Volatility (monthly σ)")
plt.ylabel("Expected Excess Return (monthly μ)")
plt.title("Mean–Variance Frontier (Excess Returns; SOFR-corrected)")
plt.grid(True, ls=":")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/numpy/linalg/_linalg.py:3383: RuntimeWarning: divide by zero encountered in matmul
#   return _core_matmul(x1, x2)
# /opt/homebrew/lib/python3.10/site-packages/numpy/linalg/_linalg.py:3383: RuntimeWarning: overflow encountered in matmul
#   return _core_matmul(x1, x2)
# /opt/homebrew/lib/python3.10/site-packages/numpy/linalg/_linalg.py:3383: RuntimeWarning: invalid value encountered in matmul
#   return _core_matmul(x1, x2)
# /var/folders/pm/ps47mfm943x_nqjshcjsk5ch0000gn/T/ipykernel_63056/2093140310.py:25: RuntimeWarning: divide by zero encountered in matmul
#   returns = W @ mu
# /var/folders/pm/ps47mfm943x_nqjshcjsk5ch0000gn/T/ipykernel_63056/2093140310.py:25: RuntimeWarning: overflow encountered in matmul
#   returns = W @ mu
# /var/folders/pm/ps47mfm943x_nqjshcjsk5ch0000gn/T/ipykernel_63056/2093140310.py:25: RuntimeWarning: invalid value encountered in matmul
#   returns = W @ mu

# %%
threshold = 0.6

corr = monthly_excess.corr()
upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))

pairs = upper.stack().reset_index()
pairs.columns = ["asset_1", "asset_2", "corr"]

most_corr = pairs[pairs["corr"].abs() > threshold].sort_values("corr", ascending=False).reset_index(drop=True)

for _, row in most_corr.iterrows():
	print(f"{row['asset_1']}  -  {row['asset_2']}: correlation = {row['corr']:.3f}")
# Out:
# BK UN Equity  -  PRU UN Equity: correlation = 0.712
# HLT UN Equity  -  RCL UN Equity: correlation = 0.690
# PRU UN Equity  -  SNA UN Equity: correlation = 0.674
# ARE UN Equity  -  UDR UN Equity: correlation = 0.664
# IVZ UN Equity  -  PRU UN Equity: correlation = 0.653
# PRU UN Equity  -  RCL UN Equity: correlation = 0.649
# BK UN Equity  -  IVZ UN Equity: correlation = 0.624
# PRU UN Equity  -  VLO UN Equity: correlation = 0.611
# GM UN Equity  -  NWSA UW Equity: correlation = 0.606
# RCL UN Equity  -  SNA UN Equity: correlation = 0.605
# GM UN Equity  -  ON UW Equity: correlation = 0.604

# %%
least_corr = pairs[pairs["corr"].abs() < threshold].copy()
least_corr["abs_corr"] = least_corr["corr"].abs()
least_corr = least_corr.sort_values("abs_corr", ascending=True).reset_index(drop=True)
least_corr = least_corr.drop(columns="abs_corr")

for _, row in least_corr.iterrows():
    print(f"{row['asset_1']}  -  {row['asset_2']}: correlation = {row['corr']:.3f}")
# Out:
# CHRW UW Equity  -  NFLX UW Equity: correlation = -0.004
# GIS UN Equity  -  JBL UN Equity: correlation = 0.004
# JBL UN Equity  -  SJM UN Equity: correlation = -0.005
# GIS UN Equity  -  RCL UN Equity: correlation = 0.021
# ATO UN Equity  -  NFLX UW Equity: correlation = 0.021
# CLX UN Equity  -  PRU UN Equity: correlation = 0.022
# NFLX UW Equity  -  PFE UN Equity: correlation = 0.031
# GIS UN Equity  -  IVZ UN Equity: correlation = 0.033
# RCL UN Equity  -  SJM UN Equity: correlation = 0.035
# CLX UN Equity  -  JBL UN Equity: correlation = 0.035
# NFLX UW Equity  -  SJM UN Equity: correlation = 0.036
# CLX UN Equity  -  NFLX UW Equity: correlation = 0.037
# GIS UN Equity  -  ON UW Equity: correlation = 0.047
# CLX UN Equity  -  RCL UN Equity: correlation = 0.048
# GIS UN Equity  -  NFLX UW Equity: correlation = -0.054
# GIS UN Equity  -  GOOGL UW Equity: correlation = 0.055
# CLX UN Equity  -  HLT UN Equity: correlation = 0.057
# ON UW Equity  -  SJM UN Equity: correlation = 0.057
# CLX UN Equity  -  IVZ UN Equity: correlation = 0.062
# GOOGL UW Equity  -  SJM UN Equity: correlation = 0.064
# CLX UN Equity  -  GOOGL UW Equity: correlation = 0.070
# BK UN Equity  -  GIS UN Equity: correlation = 0.071
# CLX UN Equity  -  NWSA UW Equity: correlation = 0.073
# SJM UN Equity  -  VLO UN Equity: correlation = 0.074
# CLX UN Equity  -  VLO UN Equity: correlation = -0.074
# CLX UN Equity  -  FCX UN Equity: correlation = -0.075
# HII UN Equity  -  NFLX UW Equity: correlation = 0.079
# CLX UN Equity  -  ON UW Equity: correlation = 0.082
# BK UN Equity  -  SJM UN Equity: correlation = 0.082
# ATO UN Equity  -  FCX UN Equity: correlation = 0.086
# NFLX UW Equity  -  ZBH UN Equity: correlation = 0.091
# GIS UN Equity  -  HLT UN Equity: correlation = 0.098
# FCX UN Equity  -  SJM UN Equity: correlation = 0.100
# GIS UN Equity  -  GM UN Equity: correlation = 0.101
# HLT UN Equity  -  SJM UN Equity: correlation = 0.108
# NFLX UW Equity  -  VLO UN Equity: correlation = 0.111
# LH UN Equity  -  SJM UN Equity: correlation = 0.112
# GIS UN Equity  -  MSCI UN Equity: correlation = 0.115
# PFE UN Equity  -  RCL UN Equity: correlation = 0.119
# BK UN Equity  -  CLX UN Equity: correlation = 0.121
# NFLX UW Equity  -  PHM UN Equity: correlation = 0.121
# ISRG UW Equity  -  SJM UN Equity: correlation = 0.128
# GIS UN Equity  -  ISRG UW Equity: correlation = 0.132
# GOOGL UW Equity  -  HII UN Equity: correlation = 0.133
# AVY UN Equity  -  CLX UN Equity: correlation = 0.136
# CLX UN Equity  -  PFE UN Equity: correlation = 0.140
# PRU UN Equity  -  SJM UN Equity: correlation = 0.144
# CLX UN Equity  -  HII UN Equity: correlation = 0.145
# NFLX UW Equity  -  UDR UN Equity: correlation = 0.145
# FCX UN Equity  -  GIS UN Equity: correlation = 0.148
# IVZ UN Equity  -  NFLX UW Equity: correlation = 0.151
# IVZ UN Equity  -  SJM UN Equity: correlation = 0.151
# FCX UN Equity  -  UDR UN Equity: correlation = 0.153
# GM UN Equity  -  SJM UN Equity: correlation = 0.156
# GIS UN Equity  -  PRU UN Equity: correlation = 0.157
# CLX UN Equity  -  SNA UN Equity: correlation = 0.158
# GM UN Equity  -  PFE UN Equity: correlation = 0.158
# FCX UN Equity  -  PFE UN Equity: correlation = 0.160
# ATO UN Equity  -  GM UN Equity: correlation = 0.163
# FCX UN Equity  -  NFLX UW Equity: correlation = 0.164
# HII UN Equity  -  UDR UN Equity: correlation = 0.164
# HLT UN Equity  -  PFE UN Equity: correlation = 0.168
# HII UN Equity  -  ISRG UW Equity: correlation = 0.169
# CLX UN Equity  -  LH UN Equity: correlation = 0.171
# GIS UN Equity  -  NWSA UW Equity: correlation = 0.172
# AVY UN Equity  -  SJM UN Equity: correlation = 0.175
# GIS UN Equity  -  VLO UN Equity: correlation = 0.175
# ISRG UW Equity  -  VLO UN Equity: correlation = 0.176
# CLX UN Equity  -  MMC UN Equity: correlation = 0.180
# IVZ UN Equity  -  PFE UN Equity: correlation = 0.181
# ATO UN Equity  -  IVZ UN Equity: correlation = 0.182
# GIS UN Equity  -  UDR UN Equity: correlation = 0.182
# MSCI UN Equity  -  SJM UN Equity: correlation = 0.185
# CHRW UW Equity  -  HII UN Equity: correlation = 0.186
# ATO UN Equity  -  ON UW Equity: correlation = 0.187
# GIS UN Equity  -  LH UN Equity: correlation = 0.188
# ATO UN Equity  -  RCL UN Equity: correlation = 0.188
# HII UN Equity  -  PFE UN Equity: correlation = 0.190
# CHRW UW Equity  -  GOOGL UW Equity: correlation = 0.190
# PFE UN Equity  -  UDR UN Equity: correlation = 0.191
# CLX UN Equity  -  ZBH UN Equity: correlation = 0.192
# CLX UN Equity  -  PHM UN Equity: correlation = 0.194
# CHRW UW Equity  -  JBL UN Equity: correlation = 0.195
# ATO UN Equity  -  VLO UN Equity: correlation = 0.196
# GM UN Equity  -  HII UN Equity: correlation = 0.199
# FCX UN Equity  -  HII UN Equity: correlation = 0.199
# MMC UN Equity  -  SJM UN Equity: correlation = 0.200
# PFE UN Equity  -  SJM UN Equity: correlation = 0.201
# CLX UN Equity  -  GM UN Equity: correlation = 0.201
# ATO UN Equity  -  GOOGL UW Equity: correlation = 0.203
# MMC UN Equity  -  NFLX UW Equity: correlation = 0.206
# ARE UN Equity  -  NFLX UW Equity: correlation = 0.209
# NFLX UW Equity  -  SNA UN Equity: correlation = 0.209
# FCX UN Equity  -  GOOGL UW Equity: correlation = 0.211
# CHRW UW Equity  -  SJM UN Equity: correlation = 0.214
# AVY UN Equity  -  NFLX UW Equity: correlation = 0.214
# JBL UN Equity  -  PFE UN Equity: correlation = 0.216
# ARE UN Equity  -  HII UN Equity: correlation = 0.216
# JBL UN Equity  -  ZBH UN Equity: correlation = 0.217
# ATO UN Equity  -  HLT UN Equity: correlation = 0.219
# SJM UN Equity  -  ZBH UN Equity: correlation = 0.219
# ATO UN Equity  -  PRU UN Equity: correlation = 0.219
# GIS UN Equity  -  PHM UN Equity: correlation = 0.222
# NFLX UW Equity  -  PRU UN Equity: correlation = 0.224
# FCX UN Equity  -  MSCI UN Equity: correlation = 0.224
# SJM UN Equity  -  UDR UN Equity: correlation = 0.225
# GOOGL UW Equity  -  PFE UN Equity: correlation = 0.225
# PFE UN Equity  -  VLO UN Equity: correlation = 0.225
# AVY UN Equity  -  GIS UN Equity: correlation = 0.226
# NWSA UW Equity  -  PFE UN Equity: correlation = 0.226
# PHM UN Equity  -  SJM UN Equity: correlation = 0.227
# GIS UN Equity  -  SNA UN Equity: correlation = 0.229
# GIS UN Equity  -  HII UN Equity: correlation = 0.230
# NWSA UW Equity  -  SJM UN Equity: correlation = 0.230
# CHRW UW Equity  -  GIS UN Equity: correlation = 0.231
# SJM UN Equity  -  SNA UN Equity: correlation = 0.231
# CHRW UW Equity  -  ON UW Equity: correlation = 0.231
# CLX UN Equity  -  MSCI UN Equity: correlation = 0.232
# CHRW UW Equity  -  CLX UN Equity: correlation = 0.237
# GIS UN Equity  -  PFE UN Equity: correlation = 0.237
# HII UN Equity  -  MSCI UN Equity: correlation = 0.238
# CHRW UW Equity  -  FCX UN Equity: correlation = 0.238
# ATO UN Equity  -  NWSA UW Equity: correlation = 0.239
# CLX UN Equity  -  UDR UN Equity: correlation = 0.241
# CHRW UW Equity  -  LH UN Equity: correlation = 0.248
# FCX UN Equity  -  ISRG UW Equity: correlation = 0.249
# GM UN Equity  -  NFLX UW Equity: correlation = 0.251
# HII UN Equity  -  RCL UN Equity: correlation = 0.253
# CLX UN Equity  -  ISRG UW Equity: correlation = 0.254
# ISRG UW Equity  -  ON UW Equity: correlation = 0.254
# BK UN Equity  -  PFE UN Equity: correlation = 0.254
# ATO UN Equity  -  BK UN Equity: correlation = 0.255
# HII UN Equity  -  NWSA UW Equity: correlation = 0.257
# HLT UN Equity  -  NFLX UW Equity: correlation = 0.258
# NFLX UW Equity  -  NWSA UW Equity: correlation = 0.261
# ATO UN Equity  -  HII UN Equity: correlation = 0.262
# ARE UN Equity  -  GIS UN Equity: correlation = 0.262
# GIS UN Equity  -  ZBH UN Equity: correlation = 0.262
# PFE UN Equity  -  ZBH UN Equity: correlation = 0.263
# FCX UN Equity  -  JBL UN Equity: correlation = 0.264
# HII UN Equity  -  ON UW Equity: correlation = 0.265
# GOOGL UW Equity  -  MMC UN Equity: correlation = 0.267
# CLX UN Equity  -  SJM UN Equity: correlation = 0.268
# JBL UN Equity  -  UDR UN Equity: correlation = 0.270
# GIS UN Equity  -  MMC UN Equity: correlation = 0.270
# CHRW UW Equity  -  GM UN Equity: correlation = 0.271
# JBL UN Equity  -  NFLX UW Equity: correlation = 0.273
# CHRW UW Equity  -  UDR UN Equity: correlation = 0.275
# HII UN Equity  -  IVZ UN Equity: correlation = 0.278
# ATO UN Equity  -  PFE UN Equity: correlation = 0.278
# HII UN Equity  -  LH UN Equity: correlation = 0.279
# ARE UN Equity  -  JBL UN Equity: correlation = 0.280
# ARE UN Equity  -  SJM UN Equity: correlation = 0.282
# ATO UN Equity  -  ZBH UN Equity: correlation = 0.284
# CHRW UW Equity  -  SNA UN Equity: correlation = 0.285
# ATO UN Equity  -  JBL UN Equity: correlation = 0.286
# HII UN Equity  -  JBL UN Equity: correlation = 0.287
# PFE UN Equity  -  PHM UN Equity: correlation = 0.287
# NFLX UW Equity  -  RCL UN Equity: correlation = 0.288
# CHRW UW Equity  -  NWSA UW Equity: correlation = 0.288
# NFLX UW Equity  -  ON UW Equity: correlation = 0.289
# ISRG UW Equity  -  IVZ UN Equity: correlation = 0.289
# GOOGL UW Equity  -  JBL UN Equity: correlation = 0.291
# ARE UN Equity  -  VLO UN Equity: correlation = 0.291
# ATO UN Equity  -  MSCI UN Equity: correlation = 0.291
# HII UN Equity  -  HLT UN Equity: correlation = 0.291
# BK UN Equity  -  NFLX UW Equity: correlation = 0.292
# AVY UN Equity  -  PFE UN Equity: correlation = 0.294
# CHRW UW Equity  -  ISRG UW Equity: correlation = 0.295
# ON UW Equity  -  PFE UN Equity: correlation = 0.297
# ARE UN Equity  -  CLX UN Equity: correlation = 0.299
# CHRW UW Equity  -  ZBH UN Equity: correlation = 0.299
# GOOGL UW Equity  -  VLO UN Equity: correlation = 0.300
# PFE UN Equity  -  SNA UN Equity: correlation = 0.300
# CHRW UW Equity  -  IVZ UN Equity: correlation = 0.300
# HII UN Equity  -  MMC UN Equity: correlation = 0.301
# ISRG UW Equity  -  JBL UN Equity: correlation = 0.302
# CHRW UW Equity  -  VLO UN Equity: correlation = 0.302
# CHRW UW Equity  -  RCL UN Equity: correlation = 0.304
# LH UN Equity  -  NFLX UW Equity: correlation = 0.304
# CHRW UW Equity  -  MSCI UN Equity: correlation = 0.306
# ON UW Equity  -  UDR UN Equity: correlation = 0.307
# CHRW UW Equity  -  PFE UN Equity: correlation = 0.307
# JBL UN Equity  -  MMC UN Equity: correlation = 0.309
# FCX UN Equity  -  PHM UN Equity: correlation = 0.309
# FCX UN Equity  -  VLO UN Equity: correlation = 0.310
# HII UN Equity  -  SJM UN Equity: correlation = 0.311
# ATO UN Equity  -  ISRG UW Equity: correlation = 0.311
# ATO UN Equity  -  SNA UN Equity: correlation = 0.311
# GM UN Equity  -  MSCI UN Equity: correlation = 0.313
# CHRW UW Equity  -  PRU UN Equity: correlation = 0.314
# MSCI UN Equity  -  SNA UN Equity: correlation = 0.315
# HII UN Equity  -  PHM UN Equity: correlation = 0.315
# GOOGL UW Equity  -  ZBH UN Equity: correlation = 0.315
# GOOGL UW Equity  -  PHM UN Equity: correlation = 0.316
# HII UN Equity  -  SNA UN Equity: correlation = 0.319
# AVY UN Equity  -  CHRW UW Equity: correlation = 0.319
# ON UW Equity  -  ZBH UN Equity: correlation = 0.320
# MSCI UN Equity  -  VLO UN Equity: correlation = 0.322
# BK UN Equity  -  HII UN Equity: correlation = 0.322
# CLX UN Equity  -  GIS UN Equity: correlation = 0.322
# ARE UN Equity  -  FCX UN Equity: correlation = 0.323
# PFE UN Equity  -  PRU UN Equity: correlation = 0.324
# ISRG UW Equity  -  UDR UN Equity: correlation = 0.324
# ATO UN Equity  -  LH UN Equity: correlation = 0.325
# BK UN Equity  -  CHRW UW Equity: correlation = 0.325
# MSCI UN Equity  -  RCL UN Equity: correlation = 0.326
# ISRG UW Equity  -  SNA UN Equity: correlation = 0.327
# AVY UN Equity  -  HII UN Equity: correlation = 0.328
# GOOGL UW Equity  -  SNA UN Equity: correlation = 0.328
# PHM UN Equity  -  VLO UN Equity: correlation = 0.331
# HII UN Equity  -  ZBH UN Equity: correlation = 0.331
# ATO UN Equity  -  AVY UN Equity: correlation = 0.333
# ARE UN Equity  -  GOOGL UW Equity: correlation = 0.333
# GM UN Equity  -  ISRG UW Equity: correlation = 0.333
# ARE UN Equity  -  GM UN Equity: correlation = 0.334
# ATO UN Equity  -  CLX UN Equity: correlation = 0.335
# GOOGL UW Equity  -  UDR UN Equity: correlation = 0.335
# BK UN Equity  -  UDR UN Equity: correlation = 0.337
# UDR UN Equity  -  VLO UN Equity: correlation = 0.339
# IVZ UN Equity  -  MSCI UN Equity: correlation = 0.343
# BK UN Equity  -  GOOGL UW Equity: correlation = 0.343
# ARE UN Equity  -  NWSA UW Equity: correlation = 0.344
# BK UN Equity  -  ZBH UN Equity: correlation = 0.344
# ATO UN Equity  -  SJM UN Equity: correlation = 0.345
# CHRW UW Equity  -  HLT UN Equity: correlation = 0.346
# ARE UN Equity  -  PFE UN Equity: correlation = 0.348
# MSCI UN Equity  -  ZBH UN Equity: correlation = 0.348
# ISRG UW Equity  -  PFE UN Equity: correlation = 0.349
# MSCI UN Equity  -  NWSA UW Equity: correlation = 0.349
# AVY UN Equity  -  JBL UN Equity: correlation = 0.350
# ATO UN Equity  -  GIS UN Equity: correlation = 0.351
# MMC UN Equity  -  ON UW Equity: correlation = 0.351
# GOOGL UW Equity  -  IVZ UN Equity: correlation = 0.352
# CHRW UW Equity  -  PHM UN Equity: correlation = 0.355
# JBL UN Equity  -  MSCI UN Equity: correlation = 0.356
# GM UN Equity  -  GOOGL UW Equity: correlation = 0.357
# ATO UN Equity  -  CHRW UW Equity: correlation = 0.357
# ISRG UW Equity  -  PHM UN Equity: correlation = 0.358
# FCX UN Equity  -  LH UN Equity: correlation = 0.359
# IVZ UN Equity  -  MMC UN Equity: correlation = 0.360
# GOOGL UW Equity  -  PRU UN Equity: correlation = 0.361
# ARE UN Equity  -  RCL UN Equity: correlation = 0.367
# UDR UN Equity  -  ZBH UN Equity: correlation = 0.367
# GM UN Equity  -  MMC UN Equity: correlation = 0.368
# MSCI UN Equity  -  PRU UN Equity: correlation = 0.369
# IVZ UN Equity  -  VLO UN Equity: correlation = 0.370
# PRU UN Equity  -  UDR UN Equity: correlation = 0.371
# GOOGL UW Equity  -  HLT UN Equity: correlation = 0.372
# AVY UN Equity  -  GOOGL UW Equity: correlation = 0.372
# MSCI UN Equity  -  PFE UN Equity: correlation = 0.374
# HII UN Equity  -  VLO UN Equity: correlation = 0.375
# BK UN Equity  -  PHM UN Equity: correlation = 0.375
# IVZ UN Equity  -  UDR UN Equity: correlation = 0.376
# JBL UN Equity  -  LH UN Equity: correlation = 0.379
# MMC UN Equity  -  VLO UN Equity: correlation = 0.379
# JBL UN Equity  -  NWSA UW Equity: correlation = 0.380
# BK UN Equity  -  ISRG UW Equity: correlation = 0.384
# LH UN Equity  -  VLO UN Equity: correlation = 0.386
# FCX UN Equity  -  RCL UN Equity: correlation = 0.388
# LH UN Equity  -  UDR UN Equity: correlation = 0.388
# LH UN Equity  -  PFE UN Equity: correlation = 0.389
# MSCI UN Equity  -  PHM UN Equity: correlation = 0.391
# GOOGL UW Equity  -  LH UN Equity: correlation = 0.391
# IVZ UN Equity  -  ZBH UN Equity: correlation = 0.394
# ARE UN Equity  -  SNA UN Equity: correlation = 0.395
# HLT UN Equity  -  IVZ UN Equity: correlation = 0.395
# NWSA UW Equity  -  UDR UN Equity: correlation = 0.397
# GM UN Equity  -  UDR UN Equity: correlation = 0.397
# PHM UN Equity  -  UDR UN Equity: correlation = 0.397
# FCX UN Equity  -  ZBH UN Equity: correlation = 0.399
# ISRG UW Equity  -  PRU UN Equity: correlation = 0.400
# FCX UN Equity  -  NWSA UW Equity: correlation = 0.401
# GM UN Equity  -  ZBH UN Equity: correlation = 0.402
# MMC UN Equity  -  RCL UN Equity: correlation = 0.403
# HII UN Equity  -  PRU UN Equity: correlation = 0.403
# JBL UN Equity  -  PHM UN Equity: correlation = 0.405
# FCX UN Equity  -  MMC UN Equity: correlation = 0.406
# ARE UN Equity  -  CHRW UW Equity: correlation = 0.406
# RCL UN Equity  -  UDR UN Equity: correlation = 0.407
# AVY UN Equity  -  VLO UN Equity: correlation = 0.408
# VLO UN Equity  -  ZBH UN Equity: correlation = 0.408
# JBL UN Equity  -  SNA UN Equity: correlation = 0.408
# GOOGL UW Equity  -  NFLX UW Equity: correlation = 0.408
# ON UW Equity  -  VLO UN Equity: correlation = 0.408
# CHRW UW Equity  -  MMC UN Equity: correlation = 0.410
# MSCI UN Equity  -  UDR UN Equity: correlation = 0.412
# JBL UN Equity  -  VLO UN Equity: correlation = 0.412
# AVY UN Equity  -  RCL UN Equity: correlation = 0.412
# FCX UN Equity  -  SNA UN Equity: correlation = 0.413
# GM UN Equity  -  PHM UN Equity: correlation = 0.414
# BK UN Equity  -  MSCI UN Equity: correlation = 0.415
# AVY UN Equity  -  UDR UN Equity: correlation = 0.415
# BK UN Equity  -  FCX UN Equity: correlation = 0.416
# BK UN Equity  -  NWSA UW Equity: correlation = 0.416
# IVZ UN Equity  -  PHM UN Equity: correlation = 0.417
# SNA UN Equity  -  UDR UN Equity: correlation = 0.417
# GOOGL UW Equity  -  NWSA UW Equity: correlation = 0.418
# HLT UN Equity  -  UDR UN Equity: correlation = 0.418
# ATO UN Equity  -  PHM UN Equity: correlation = 0.418
# FCX UN Equity  -  IVZ UN Equity: correlation = 0.418
# ISRG UW Equity  -  RCL UN Equity: correlation = 0.419
# ATO UN Equity  -  MMC UN Equity: correlation = 0.419
# ISRG UW Equity  -  NWSA UW Equity: correlation = 0.421
# AVY UN Equity  -  ISRG UW Equity: correlation = 0.422
# HLT UN Equity  -  MSCI UN Equity: correlation = 0.423
# MSCI UN Equity  -  ON UW Equity: correlation = 0.424
# IVZ UN Equity  -  JBL UN Equity: correlation = 0.425
# ARE UN Equity  -  ON UW Equity: correlation = 0.426
# GOOGL UW Equity  -  ON UW Equity: correlation = 0.427
# AVY UN Equity  -  FCX UN Equity: correlation = 0.427
# PHM UN Equity  -  RCL UN Equity: correlation = 0.429
# LH UN Equity  -  RCL UN Equity: correlation = 0.430
# AVY UN Equity  -  GM UN Equity: correlation = 0.430
# GOOGL UW Equity  -  ISRG UW Equity: correlation = 0.432
# ON UW Equity  -  PHM UN Equity: correlation = 0.435
# FCX UN Equity  -  GM UN Equity: correlation = 0.435
# ISRG UW Equity  -  NFLX UW Equity: correlation = 0.436
# ARE UN Equity  -  ISRG UW Equity: correlation = 0.438
# GM UN Equity  -  JBL UN Equity: correlation = 0.438
# AVY UN Equity  -  PHM UN Equity: correlation = 0.439
# HLT UN Equity  -  PHM UN Equity: correlation = 0.439
# BK UN Equity  -  LH UN Equity: correlation = 0.442
# HLT UN Equity  -  JBL UN Equity: correlation = 0.442
# MMC UN Equity  -  PFE UN Equity: correlation = 0.443
# IVZ UN Equity  -  RCL UN Equity: correlation = 0.446
# BK UN Equity  -  ON UW Equity: correlation = 0.447
# ARE UN Equity  -  BK UN Equity: correlation = 0.447
# GM UN Equity  -  VLO UN Equity: correlation = 0.448
# LH UN Equity  -  ON UW Equity: correlation = 0.451
# FCX UN Equity  -  ON UW Equity: correlation = 0.452
# NWSA UW Equity  -  ON UW Equity: correlation = 0.456
# HLT UN Equity  -  ISRG UW Equity: correlation = 0.458
# HLT UN Equity  -  LH UN Equity: correlation = 0.458
# ARE UN Equity  -  IVZ UN Equity: correlation = 0.458
# ARE UN Equity  -  ZBH UN Equity: correlation = 0.459
# GOOGL UW Equity  -  RCL UN Equity: correlation = 0.460
# LH UN Equity  -  NWSA UW Equity: correlation = 0.460
# IVZ UN Equity  -  LH UN Equity: correlation = 0.461
# GM UN Equity  -  LH UN Equity: correlation = 0.462
# NWSA UW Equity  -  PHM UN Equity: correlation = 0.463
# JBL UN Equity  -  RCL UN Equity: correlation = 0.463
# MMC UN Equity  -  UDR UN Equity: correlation = 0.464
# BK UN Equity  -  JBL UN Equity: correlation = 0.465
# HLT UN Equity  -  ZBH UN Equity: correlation = 0.466
# JBL UN Equity  -  PRU UN Equity: correlation = 0.466
# NWSA UW Equity  -  VLO UN Equity: correlation = 0.468
# ARE UN Equity  -  PRU UN Equity: correlation = 0.469
# BK UN Equity  -  MMC UN Equity: correlation = 0.470
# HLT UN Equity  -  ON UW Equity: correlation = 0.471
# GOOGL UW Equity  -  MSCI UN Equity: correlation = 0.473
# RCL UN Equity  -  ZBH UN Equity: correlation = 0.474
# ON UW Equity  -  RCL UN Equity: correlation = 0.474
# HLT UN Equity  -  VLO UN Equity: correlation = 0.475
# AVY UN Equity  -  NWSA UW Equity: correlation = 0.476
# MMC UN Equity  -  MSCI UN Equity: correlation = 0.476
# PHM UN Equity  -  PRU UN Equity: correlation = 0.477
# ISRG UW Equity  -  LH UN Equity: correlation = 0.477
# ARE UN Equity  -  HLT UN Equity: correlation = 0.483
# AVY UN Equity  -  ZBH UN Equity: correlation = 0.483
# BK UN Equity  -  HLT UN Equity: correlation = 0.484
# ISRG UW Equity  -  ZBH UN Equity: correlation = 0.485
# NWSA UW Equity  -  ZBH UN Equity: correlation = 0.488
# ATO UN Equity  -  UDR UN Equity: correlation = 0.491
# ON UW Equity  -  SNA UN Equity: correlation = 0.491
# IVZ UN Equity  -  NWSA UW Equity: correlation = 0.492
# AVY UN Equity  -  BK UN Equity: correlation = 0.493
# ARE UN Equity  -  ATO UN Equity: correlation = 0.493
# BK UN Equity  -  VLO UN Equity: correlation = 0.493
# AVY UN Equity  -  LH UN Equity: correlation = 0.494
# AVY UN Equity  -  IVZ UN Equity: correlation = 0.496
# ARE UN Equity  -  PHM UN Equity: correlation = 0.496
# MMC UN Equity  -  NWSA UW Equity: correlation = 0.497
# HLT UN Equity  -  SNA UN Equity: correlation = 0.498
# MSCI UN Equity  -  NFLX UW Equity: correlation = 0.499
# AVY UN Equity  -  MSCI UN Equity: correlation = 0.500
# MMC UN Equity  -  SNA UN Equity: correlation = 0.502
# MMC UN Equity  -  ZBH UN Equity: correlation = 0.502
# AVY UN Equity  -  ON UW Equity: correlation = 0.505
# ON UW Equity  -  PRU UN Equity: correlation = 0.506
# PRU UN Equity  -  ZBH UN Equity: correlation = 0.506
# LH UN Equity  -  MSCI UN Equity: correlation = 0.508
# FCX UN Equity  -  PRU UN Equity: correlation = 0.509
# LH UN Equity  -  PRU UN Equity: correlation = 0.510
# BK UN Equity  -  RCL UN Equity: correlation = 0.512
# ISRG UW Equity  -  MSCI UN Equity: correlation = 0.516
# MMC UN Equity  -  PHM UN Equity: correlation = 0.517
# SNA UN Equity  -  VLO UN Equity: correlation = 0.519
# PHM UN Equity  -  ZBH UN Equity: correlation = 0.526
# SNA UN Equity  -  ZBH UN Equity: correlation = 0.526
# AVY UN Equity  -  SNA UN Equity: correlation = 0.528
# AVY UN Equity  -  HLT UN Equity: correlation = 0.528
# HLT UN Equity  -  MMC UN Equity: correlation = 0.529
# ARE UN Equity  -  AVY UN Equity: correlation = 0.531
# LH UN Equity  -  MMC UN Equity: correlation = 0.534
# ARE UN Equity  -  MMC UN Equity: correlation = 0.535
# GM UN Equity  -  SNA UN Equity: correlation = 0.540
# NWSA UW Equity  -  SNA UN Equity: correlation = 0.540
# GM UN Equity  -  HLT UN Equity: correlation = 0.541
# IVZ UN Equity  -  ON UW Equity: correlation = 0.541
# BK UN Equity  -  GM UN Equity: correlation = 0.542
# RCL UN Equity  -  VLO UN Equity: correlation = 0.543
# GM UN Equity  -  RCL UN Equity: correlation = 0.543
# GM UN Equity  -  IVZ UN Equity: correlation = 0.545
# ARE UN Equity  -  LH UN Equity: correlation = 0.550
# AVY UN Equity  -  PRU UN Equity: correlation = 0.550
# PHM UN Equity  -  SNA UN Equity: correlation = 0.551
# AVY UN Equity  -  MMC UN Equity: correlation = 0.555
# GIS UN Equity  -  SJM UN Equity: correlation = 0.559
# HLT UN Equity  -  NWSA UW Equity: correlation = 0.559
# FCX UN Equity  -  HLT UN Equity: correlation = 0.562
# BK UN Equity  -  SNA UN Equity: correlation = 0.568
# ISRG UW Equity  -  MMC UN Equity: correlation = 0.568
# LH UN Equity  -  ZBH UN Equity: correlation = 0.569
# NWSA UW Equity  -  RCL UN Equity: correlation = 0.577
# NWSA UW Equity  -  PRU UN Equity: correlation = 0.578
# IVZ UN Equity  -  SNA UN Equity: correlation = 0.579
# LH UN Equity  -  PHM UN Equity: correlation = 0.580
# JBL UN Equity  -  ON UW Equity: correlation = 0.580
# LH UN Equity  -  SNA UN Equity: correlation = 0.581
# ARE UN Equity  -  MSCI UN Equity: correlation = 0.583
# GM UN Equity  -  PRU UN Equity: correlation = 0.588
# MMC UN Equity  -  PRU UN Equity: correlation = 0.592
# HLT UN Equity  -  PRU UN Equity: correlation = 0.598

# %%
corr = monthly_excess.corr()
upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
pairs = upper.stack().reset_index()
pairs.columns = ["asset_1", "asset_2", "corr"]

k = 10
top_pos = pairs.sort_values("corr", ascending=False).head(k)
top_neg = pairs.sort_values("corr", ascending=True).head(k)

print("\nMost positively correlated:")
for _, r in top_pos.iterrows():
    print(f"{r['asset_1']} - {r['asset_2']}: {r['corr']:.3f}")

print("\nMost negatively correlated:")
for _, r in top_neg.iterrows():
    print(f"{r['asset_1']} - {r['asset_2']}: {r['corr']:.3f}")
# Out:
# Most positively correlated:
# BK UN Equity - PRU UN Equity: 0.712
# HLT UN Equity - RCL UN Equity: 0.690
# PRU UN Equity - SNA UN Equity: 0.674
# ARE UN Equity - UDR UN Equity: 0.664
# IVZ UN Equity - PRU UN Equity: 0.653
# PRU UN Equity - RCL UN Equity: 0.649
# BK UN Equity - IVZ UN Equity: 0.624
# PRU UN Equity - VLO UN Equity: 0.611
# GM UN Equity - NWSA UW Equity: 0.606
# RCL UN Equity - SNA UN Equity: 0.605
#
# Most negatively correlated:
# CLX UN Equity - FCX UN Equity: -0.075
# CLX UN Equity - VLO UN Equity: -0.074
# GIS UN Equity - NFLX UW Equity: -0.054
# JBL UN Equity - SJM UN Equity: -0.005
# CHRW UW Equity - NFLX UW Equity: -0.004
# GIS UN Equity - JBL UN Equity: 0.004
# GIS UN Equity - RCL UN Equity: 0.021
# ATO UN Equity - NFLX UW Equity: 0.021
# CLX UN Equity - PRU UN Equity: 0.022
# NFLX UW Equity - PFE UN Equity: 0.031

# %%
pair = ("CLX UN Equity", "FCX UN Equity")
cols = [c for c in pair if c in monthly_excess.columns]
if len(cols) < 2:
    cols = monthly_excess.columns[:2].tolist()
a, b = cols

R = monthly_excess[[a, b]].dropna()
mu1, mu2 = R.mean().values
s1, s2   = R.std().values
rho_emp  = float(R.corr().iloc[0,1])

def two_asset_frontier(mu1, mu2, s1, s2, rho, w):
    ret = w*mu1 + (1-w)*mu2
    var = (w**2)*(s1**2) + ((1-w)**2)*(s2**2) + 2*w*(1-w)*rho*s1*s2
    return ret, np.sqrt(np.maximum(var, 0.0))

def gmv_weight(s1, s2, rho):
    num = s2**2 - rho*s1*s2
    den = s1**2 + s2**2 - 2*rho*s1*s2
    w = num / den
    return np.clip(w, 0.0, 1.0)


rhos = [1.0, 0.9, 0.7, 0.0, -0.07, -0.9, -1.0, rho_emp]
labels = {
    1.0:   "ρ=+1.00 (no benefit)",
    0.9:   "ρ=+0.90",
    0.7:   "ρ≈+0.70 (e.g., BK-PRU / HLT-RCL)",
    0.0:   "ρ=0.00",
    -0.07: "ρ≈-0.07 (e.g., CLX-FCX / CLX-VLO)",
    -0.9:  "ρ=-0.90",
    -1.0:  "ρ=-1.00 (zero-variance mix exists)",
}

w = np.linspace(0.0, 1.0, 401)

plt.figure(figsize=(8, 6))
for rho in rhos:
    ret, vol = two_asset_frontier(mu1, mu2, s1, s2, rho, w)
    if rho == rho_emp:
        plt.plot(vol, ret, lw=2.5, label=f"empirical ρ={rho_emp:.3f}", alpha=0.95)
    else:
        plt.plot(vol, ret, lw=1.5, ls="--", label=labels.get(rho, f"ρ={rho:.2f}"))
    wg = gmv_weight(s1, s2, rho)
    rg, sg = two_asset_frontier(mu1, mu2, s1, s2, rho, wg)
    plt.scatter([sg], [rg], s=36, zorder=3)


plt.scatter([s1, s2], [mu1, mu2], s=54, zorder=4)
plt.annotate(a, (s1, mu1), xytext=(6, 6), textcoords="offset points", fontsize=9)
plt.annotate(b, (s2, mu2), xytext=(6, 6), textcoords="offset points", fontsize=9)

plt.xlabel("Volatility (σ, monthly)")
plt.ylabel("Expected Excess Return (μ, monthly)")
plt.title(f"Two-Asset Mean-Variance Frontiers for {a} & {b}")
plt.grid(True, ls=":")
plt.legend()
plt.tight_layout()
plt.show()


rows = []
for rho in [1.0, 0.7, 0.0, -0.07, -1.0, rho_emp]:
    wg = gmv_weight(s1, s2, rho)
    rg, sg = two_asset_frontier(mu1, mu2, s1, s2, rho, wg)
    rows.append({"rho": float(rho if rho != rho_emp else rho_emp),
        		"w_"+a: float(wg), "w_"+b: float(1-wg),
                "mu_p": float(rg), "sigma_p": float(sg)})
gmv_table = pd.DataFrame(rows)
print(gmv_table.to_string(index=False))
# Out:
#       rho  w_CLX UN Equity  w_FCX UN Equity     mu_p      sigma_p
#  1.000000         1.000000         0.000000 0.005413 6.003921e-02
#  0.700000         1.000000         0.000000 0.005413 6.003921e-02
#  0.000000         0.877354         0.122646 0.006444 5.623705e-02
# -0.070000         0.860786         0.139214 0.006583 5.485368e-02
# -1.000000         0.727863         0.272137 0.007700 6.585445e-10
# -0.074507         0.859769         0.140231 0.006592 5.475839e-02

# %% [markdown]
# # Project 3

# %% [markdown]
# Calculating the Betas for the 30 stocks
#
# $$
# \beta_i = \frac{Cov(R_i, R_m)}{Var(R_m)}
# $$

# %%
]
